# %%
import tensorflow as tf
from tensorflow import keras

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.6/dist-packages (1.0.1)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (3.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.8.7)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.18.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.22.2.post1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->keras-tuner) (0.16.0)

# %%
import numpy as np
import pandas as pd

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
fashion_mnist=keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
train_images=train_images.reshape(len(train_images),28,28,1)

# %%
test_images=test_images.reshape(len(test_images),28,28,1)

# %%
def build_model(hp):
  model=keras.Sequential([
                          keras.layers.Conv2D(filters=hp.Int('conv_1_filter',min_value=32,max_value=128,step=16),
                                              kernel_size=hp.Choice('conv_1_kernel',values=[3,5]),
                                              activation='relu',
                                              input_shape=(28,28,1),
                                              ),
                          keras.layers.Conv2D(filters=hp.Int('conv_2_filter',min_value=32,max_value=64,step=16),
                                              kernel_size=hp.Choice('conv_1_kernel',values=[3,5]),
                                              activation='relu',
                          ),
                          keras.layers.Flatten(),
                          keras.layers.Dense(
                              units=hp.Int('dense_1_units',min_value=32,max_value=128,step=16),
                              activation='relu'
                          ),
                          keras.layers.Dense(10,activation='softmax')
                          
  ])
  model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate',values=[1e-2,1e-3])),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
# !pip install keras-tuner
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.6/dist-packages (1.0.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.22.2.post1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.8.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (3.1.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->keras-tuner) (0.16.0)

# %%
tuner_search=RandomSearch(build_model,objective='val_accuracy',max_trials=5,directory='output',project_name='Mnist_Fashion')

# %%
tuner_search.search(train_images,train_labels,epochs=3,validation_split=0.1)
# Out:
# Epoch 1/3
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4100 - accuracy: 0.8514 - val_loss: 0.3159 - val_accuracy: 0.8848
# Epoch 2/3
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2690 - accuracy: 0.9001 - val_loss: 0.2699 - val_accuracy: 0.9000
# Epoch 3/3
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2130 - accuracy: 0.9206 - val_loss: 0.2574 - val_accuracy: 0.9083
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: e6f1b8b2a9942c57d33bca5eeed3710b</span>
# <span style="color:cyan"> |-Score: 0.9083333611488342</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_1_filter: 96</span>
# <span style="color:blue"> |-conv_1_kernel: 5</span>
# <span style="color:cyan"> |-conv_2_filter: 48</span>
# <span style="color:blue"> |-dense_1_units: 112</span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# Epoch 1/3
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.4157 - accuracy: 0.8501 - val_loss: 0.3305 - val_accuracy: 0.8785
# Epoch 2/3
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2736 - accuracy: 0.8999 - val_loss: 0.2641 - val_accuracy: 0.8995
# Epoch 3/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2212 - accuracy: 0.9175 - val_loss: 0.2572 - val_accuracy: 0.9082
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: ba53d30e3e64b9f120f877ed6838bc16</span>
# <span style="color:cyan"> |-Score: 0.9081666469573975</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_1_filter: 96</span>
# <span style="color:blue"> |-conv_1_kernel: 5</span>
# <span style="color:cyan"> |-conv_2_filter: 48</span>
# <span style="color:blue"> |-dense_1_units: 64</span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# Epoch 1/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4569 - accuracy: 0.8396 - val_loss: 0.3574 - val_accuracy: 0.8688
# Epoch 2/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3272 - accuracy: 0.8809 - val_loss: 0.4077 - val_accuracy: 0.8462
# Epoch 3/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2994 - accuracy: 0.8914 - val_loss: 0.3625 - val_accuracy: 0.8722
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: adcb04fb361cfcb4f15ece5983a34930</span>
# <span style="color:cyan"> |-Score: 0.8721666932106018</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_1_filter: 112</span>
# <span style="color:blue"> |-conv_1_kernel: 3</span>
# <span style="color:cyan"> |-conv_2_filter: 32</span>
# <span style="color:blue"> |-dense_1_units: 112</span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# Epoch 1/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4054 - accuracy: 0.8537 - val_loss: 0.3211 - val_accuracy: 0.8788
# Epoch 2/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2621 - accuracy: 0.9047 - val_loss: 0.2695 - val_accuracy: 0.9005
# Epoch 3/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2074 - accuracy: 0.9219 - val_loss: 0.2646 - val_accuracy: 0.9057
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 9e53c55eb5651da7711c346f6ae2513d</span>
# <span style="color:cyan"> |-Score: 0.9056666493415833</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_1_filter: 48</span>
# <span style="color:blue"> |-conv_1_kernel: 5</span>
# <span style="color:cyan"> |-conv_2_filter: 64</span>
# <span style="color:blue"> |-dense_1_units: 80</span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# Epoch 1/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4601 - accuracy: 0.8356 - val_loss: 0.3427 - val_accuracy: 0.8757
# Epoch 2/3
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3357 - accuracy: 0.8762 - val_loss: 0.3492 - val_accuracy: 0.8775
# Epoch 3/3
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2990 - accuracy: 0.8897 - val_loss: 0.3592 - val_accuracy: 0.8792
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 17b766170f8ac4992f94f9467b67f4c2</span>
# <span style="color:cyan"> |-Score: 0.8791666626930237</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_1_filter: 96</span>
# <span style="color:blue"> |-conv_1_kernel: 3</span>
# <span style="color:cyan"> |-conv_2_filter: 64</span>
# <span style="color:blue"> |-dense_1_units: 48</span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# INFO:tensorflow:Oracle triggered exit

# %%
model=tuner_search.get_best_models(num_models=1)[0]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 96)        2496
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 48)        115248
# _________________________________________________________________
# flatten (Flatten)            (None, 19200)             0
# _________________________________________________________________
# dense (Dense)                (None, 112)               2150512
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1130
# =================================================================
# Total params: 2,269,386
# Trainable params: 2,269,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_images,train_labels,epochs=10,validation_split=0.1,initial_epoch=2)
# Out:
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1675 - accuracy: 0.9368 - val_loss: 0.2585 - val_accuracy: 0.9150
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1286 - accuracy: 0.9522 - val_loss: 0.2873 - val_accuracy: 0.9103
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1010 - accuracy: 0.9624 - val_loss: 0.3154 - val_accuracy: 0.9077
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0785 - accuracy: 0.9710 - val_loss: 0.3452 - val_accuracy: 0.9103
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0595 - accuracy: 0.9780 - val_loss: 0.3911 - val_accuracy: 0.9133
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0495 - accuracy: 0.9814 - val_loss: 0.4450 - val_accuracy: 0.9100
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0402 - accuracy: 0.9849 - val_loss: 0.4745 - val_accuracy: 0.9082
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0369 - accuracy: 0.9869 - val_loss: 0.4964 - val_accuracy: 0.9098
