# %%
import tensorflow as tf
import keras as k

# %%
x=k.Variable(4,name='x')
y=k.Variable(3,name='y')
f=x*x*y+y+2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-80891a4d36b9> in <module>()
# ----> 1 x=k.Variable(4,name='x')
#       2 y=k.Variable(3,name='y')
#       3 f=x*x*y+y+2
#
# AttributeError: module 'keras' has no attribute 'Variable'

# %%
with tf.Session() as sess:
  x.initializer.run()
  y.initializer.run()
  result = f.eval()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3bdb22038c14> in <module>()
# ----> 1 with tf.Session() as sess:
#       2   x.initializer.run()
#       3   y.initializer.run()
#       4   result = f.eval()
#
# AttributeError: module 'tensorflow' has no attribute 'Session'
